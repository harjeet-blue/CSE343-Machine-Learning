# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ca7a0423-28cb-46b3-a40e-ef311cc79a44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca7a0423-28cb-46b3-a40e-ef311cc79a44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import utils_harjeet
everything = utils_harjeet.basic()
dataset = utils_harjeet.dataset()
# Out:
# Datapoints: 1000

# %%
# Out:
# Datapoints: 1000

# %%
add_noise=False
without_noise = dataset.get(add_noise)
everything.graph_plot(without_noise,0,[0,0,0])

w_without_noise = everything.PercepAlgo1(without_noise,[0.01,0.01,0.01])
everything.graph_plot(without_noise,1,w_without_noise)

w_without_noise = everything.PercepAlgo2(without_noise,[0.01,0.01,0.01])
everything.graph_plot(without_noise,1,w_without_noise)

# %%
add_noise=True
with_noise = dataset.get(add_noise)
everything.graph_plot(with_noise,0,[0,0,0])

w_with_noise = everything.PercepAlgo1(with_noise,[0.01,0.01,0.01])
everything.graph_plot(with_noise,1,w_with_noise)

w_with_noise = everything.PercepAlgo2(with_noise,[0.01,0.01,0.01])
everything.graph_plot(with_noise,1,w_with_noise)

# %%
xor_data = everything.generate_data_xor_or_and('xor')
w_xor = everything.PercepAlgo1(xor_data,[0.01,0.01,0.01])
everything.graph_plot(xor_data,1,w_xor)

w_xor = everything.PercepAlgo2(xor_data,[0.01,0.01,0.01])
everything.graph_plot(xor_data,1,w_xor)

# %%
or_data = everything.generate_data_xor_or_and('or')
w_or = everything.PercepAlgo1(or_data,[0.01,0.01,0.01])
everything.graph_plot(or_data,1,w_or)

w_or = everything.PercepAlgo2(or_data,[0.01,0.01,0.01])
everything.graph_plot(or_data,1,w_or)

# %%
and_data = everything.generate_data_xor_or_and('and')
w_and = everything.PercepAlgo1(and_data,[0.01,0.01,0.01])
everything.graph_plot(and_data,1,w_and)

w_and = everything.PercepAlgo2(and_data,[0.01,0.01,0.01])
everything.graph_plot(and_data,1,w_and)
